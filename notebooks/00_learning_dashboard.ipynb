# %% [markdown]
# # AI FDE Learning Dashboard
#
# This is the front door to the learning system. GitHub is being used as the **memory layer** so that the important reasoning from course + ChatGPT + hands-on practice is preserved instead of disappearing into chat history.
#
# ## Current learning node
#
# **Python fundamentals → ML foundations → Simple Linear Regression → Multiple Linear Regression → Model Evaluation / R²**

# %% [markdown]
# ## Core notebooks created
#
# 1. `00_python_to_ml_bridge.ipynb` — lists, indexing, loops, accumulators, functions, dictionaries connected to ML.
# 2. `01_ml_foundations.ipynb` — numerical/categorical, X/Y, supervised/unsupervised/reinforcement, regression/classification.
# 3. `02_simple_linear_regression.ipynb` — full arithmetic from mean → deviations → slope → intercept → prediction → residual → SSE/MSE/RMSE → sklearn.
# 4. `03_multiple_linear_regression.ipynb` — multiple features, Pandas, correlation, one-hot encoding, train/test split, fit/predict, coefficients.
# 5. `04_model_evaluation_r2.ipynb` — R², interpretation, MAE/MSE/RMSE, generalization, leakage.

# %% [markdown]
# ## Learning-memory files
#
# - `notes/LESSON_DNA_TEMPLATE.md` — the 13-part quality standard for every future lesson.
# - `notes/2026-08-07_regression_learning_session.md` — preserved reasoning journey from the course/audio discussion and handwritten exercises.
# - `notes/ai_commando_learning_map.md` — overall AI Commando/FDE learning map.
#
# The notebooks are executable learning artifacts; the session notes preserve **why we understood something in a particular way**.

# %% [markdown]
# ## 13-part Learning DNA
#
# Every important lesson should contain:
#
# 1. Source/course context
# 2. Core definition
# 3. Plain-English mental model
# 4. Analogy / visual intuition
# 5. Mathematics / arithmetic from the root
# 6. From-scratch Python
# 7. Visualization + interpretation
# 8. Library / production version
# 9. Data-engineering connection
# 10. Pharma + PlantMind application
# 11. Corrections / failure modes
# 12. Rebuild + break exercises
# 13. Explain-back / mastery / gap log

# %% [markdown]
# ## Working rule — preserve learning, not just final code
#
# A code cell such as:
#
# ```python
# model.fit(X_train, y_train)
# ```
#
# is incomplete as a learning artifact unless the notebook also preserves what `fit()` means under the hood, why the data was split, what parameters are learned, how performance is evaluated, and where the approach can fail.

# %% [markdown]
# ## Course capture workflow
#
# ```text
# course/audio chunk
#       ↓
# capture without interruption
#       ↓
# deep-dive when requested
#       ↓
# correct misconceptions
#       ↓
# math/arithmetic
#       ↓
# basic Python
#       ↓
# library implementation
#       ↓
# Pharma + PlantMind application
#       ↓
# exercise / explain back
#       ↓
# commit to GitHub
# ```

# %% [markdown]
# ## Environment
#
# - **GitHub** = source of truth + version history + learning memory
# - **VS Code** = local development/rebuild workspace
# - **Google Colab** = browser/cloud notebook execution
# - **ChatGPT** = tutor + learning architect + GitHub maintainer
#
# Use public/synthetic/personal learning data only. Never commit client/LTTS/Jazz-sensitive data, credentials, documents, or proprietary code to this public repository.

# %%
import sys
print('Python:', sys.version.split()[0])
print('AI FDE Learning Lab ready')

# %% [markdown]
# ## Next checkpoint
#
# 1. Run `02_simple_linear_regression.ipynb` end-to-end.
# 2. Rebuild slope/intercept without looking.
# 3. Move to the multiple-regression exercise.
# 4. Evaluate with R² + MAE/RMSE.
# 5. Continue the AI Commando ML curriculum and preserve each important lesson using the same DNA.
