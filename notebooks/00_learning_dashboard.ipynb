# %% [markdown]
# # AI FDE Learning Dashboard
#
# This notebook is the front door to the learning lab.
#
# ## Current node
# **Machine Learning Foundations → Simple Linear Regression → Multiple Linear Regression → Model Evaluation**
#
# ## Learning DNA
# 1. 📘 Theory
# 2. 🧠 Intuition
# 3. 🔢 Math
# 4. 💻 From-scratch Python
# 5. 📊 Visualization
# 6. ⚡ Library implementation
# 7. 🏗️ Data-engineering connection
# 8. 💊 Pharma application
# 9. 🌱 PlantMind application
# 10. 🧪 Exercise
# 11. ✅ Validation
# 12. ❓ Questions / gaps

# %% [markdown]
# ## Environment check
# Run the next cell in Colab or VS Code/Jupyter.

# %%
import sys
print('Python:', sys.version.split()[0])
print('AI FDE Learning Lab ready')

# %% [markdown]
# ## Working rules
# - GitHub is the source of truth.
# - Use public/synthetic data only.
# - Do not edit the same notebook in Colab and VS Code at the same time.
# - Prefer understanding and rebuilding over copy-paste.
# - Commit meaningful learning checkpoints.
